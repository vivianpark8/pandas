# %%
import numpy as np
import pandas as pd

# %%
excel = pd.read_excel('data/DAMF2.xlsx')

# %%
excel
# Out:
#      이름                             전공                     email  \
# 0   오창희                        소프트웨어공학        oche.edu@gmail.com
# 1   권기남                         항공전기전공        rlska213@naver.com
# 2   김광성                           경제학과         kgs3770@gmail.com
# 3   김승현                           음악학과     tmdgus_skfk@naver.com
# 4   김윤식                         중국통상학과        manylong@naver.com
# 5   김주성                            사회학   kimjs20020426@gmail.com
# 6   민예린                         정보통신학과        yerinmin@naver.com
# 7   박선민                      콘텐츠 비즈니스       manimoun99@gmail.com
# 8   박소리                    미디어커뮤니케이션학부   alsldjsthflone@daum.net
# 9   박수빈               한문학과/미디어커뮤니케이션학과        tvsu0808@gmail.com
# 10  박수현  Big Data in Culture & Society    iamsummer614@gmail.com
# 11  신효진                          일본어통역    dsvit100hjin@gmail.com
# 12  양다희                  수리금융학과/응용통계학과       sally8323@gmail.com
# ...

# %%
excel['이름']
# Out:
# 0     오창희
# 1     권기남
# 2     김광성
# 3     김승현
# 4     김윤식
# 5     김주성
# 6     민예린
# 7     박선민
# 8     박소리
# 9     박수빈
# 10    박수현
# 11    신효진
# 12    양다희
# 13    이유진
# 14    이주현
# 15    임서영
# 16    장윤서
# 17    조중석
# 18    최민혁
# 19    최시언
# 20    황다인
# 21    황성진
# Name: 이름, dtype: object

# %%
excel[['이름', 'github']]
# Out:
#      이름          github
# 0   오창희         5chang2
# 1   권기남          kka712
# 2   김광성         kgs3770
# 3   김승현         wnshite
# 4   김윤식     rladbstlr87
# 5   김주성       darkmonke
# 6   민예린    Yerineeeee98
# 7   박선민      manimo1234
# 8   박소리         alslsol
# 9   박수빈     vivianpark8
# 10  박수현       iam-Aerin
# 11  신효진        DSVIT100
# 12  양다희        dahee325
# 13  이유진         eyoojin
# 14  이주현        Lejuhyun
# 15  임서영    seoyoung1203
# 16  장윤서  jangyunseo4547
# 17  조중석     Chojungseok
# 18  최민혁    Minhyeok0330
# 19  최시언       choisieon
# 20  황다인        dain0628
# 21  황성진    seongjin5743

# %%
excel.head()
# Out:
#     이름       전공                  email       github
# 0  오창희  소프트웨어공학     oche.edu@gmail.com      5chang2
# 1  권기남   항공전기전공     rlska213@naver.com       kka712
# 2  김광성     경제학과      kgs3770@gmail.com      kgs3770
# 3  김승현     음악학과  tmdgus_skfk@naver.com      wnshite
# 4  김윤식   중국통상학과     manylong@naver.com  rladbstlr87

# %%
excel = pd.read_excel('data/DAMF2.xlsx', sheet_name='menu')
excel.head()
# Out:
#         가게이름   시간                       메뉴  \
# 0     독립문설렁탕   5분                  설랑탕/불고기
# 1        송준옥   8분                 맑은뼈국(국밥)
# 2       종로김밥  NaN                       분식
# 3  바지락수제비칼국수   8분               수제비,칼국수,김밥
# 4      유닭스토리   3분  닭(칼국수, 곰탕, 계장)\n닭갈비치즈덮밥
#
#                                                  한줄평
# 0                             설렁탕이 6천원! / 하지만 웨이팅 있음
# 1  보통11,000원/특14,000원 bar형식의 테이블로 3~4명가면 일렬로 앉아야되...
# 2            2/12 방문기준 신촌역점은 영업 안했어요! 신촌로터리점은 안가봤어요!
# 3  칼국수, 수제비, 칼제비 5,000원 김밥 3,000원 / 자리가 협소해서 2-3팀...
# 4                               10,000~11,000원/자리많아요

# %%
pd.read_excel('data/DAMF2.xlsx', sheet_name=None)
# Out:
# {'info':      이름                             전공                     email  \
#  0   오창희                        소프트웨어공학        oche.edu@gmail.com
#  1   권기남                         항공전기전공        rlska213@naver.com
#  2   김광성                           경제학과         kgs3770@gmail.com
#  3   김승현                           음악학과     tmdgus_skfk@naver.com
#  4   김윤식                         중국통상학과        manylong@naver.com
#  5   김주성                            사회학   kimjs20020426@gmail.com
#  6   민예린                         정보통신학과        yerinmin@naver.com
#  7   박선민                      콘텐츠 비즈니스       manimoun99@gmail.com
#  8   박소리                    미디어커뮤니케이션학부   alsldjsthflone@daum.net
#  9   박수빈               한문학과/미디어커뮤니케이션학과        tvsu0808@gmail.com
#  10  박수현  Big Data in Culture & Society    iamsummer614@gmail.com
#  11  신효진                          일본어통역    dsvit100hjin@gmail.com
#  12  양다희                  수리금융학과/응용통계학과       sally8323@gmail.com
# ...

# %%
menu_df = excel[['가게이름', '메뉴']]

# %%
menu_df.head()
# Out:
#         가게이름                       메뉴
# 0     독립문설렁탕                  설랑탕/불고기
# 1        송준옥                 맑은뼈국(국밥)
# 2       종로김밥                       분식
# 3  바지락수제비칼국수               수제비,칼국수,김밥
# 4      유닭스토리  닭(칼국수, 곰탕, 계장)\n닭갈비치즈덮밥

# %%
menu_df.to_excel('data/sample.xlsx', index=False)

# %% [markdown]
# ### CSV

# %%
df = pd.read_csv('data/DAMF2.csv')

# %%
df
# Out:
#       이름       전공                  email       github
# 0    오창희  소프트웨어공학     oche.edu@gmail.com      5chang2
# 1    권기남   항공전기전공     rlska213@naver.com       kka712
# 2    김광성     경제학과      kgs3770@gmail.com      kgs3770
# 3    김승현     음악학과  tmdgus_skfk@naver.com      wnshite
# 4    김윤식   중국통상학과     manylong@naver.com  rladbstlr87
# ..   ...      ...                    ...          ...
# 991  NaN      NaN                    NaN          NaN
# 992  NaN      NaN                    NaN          NaN
# 993  NaN      NaN                    NaN          NaN
# 994  NaN      NaN                    NaN          NaN
# 995  NaN      NaN                    NaN          NaN
#
# [996 rows x 4 columns]

# %%
df.head()
# Out:
#     이름       전공                  email       github
# 0  오창희  소프트웨어공학     oche.edu@gmail.com      5chang2
# 1  권기남   항공전기전공     rlska213@naver.com       kka712
# 2  김광성     경제학과      kgs3770@gmail.com      kgs3770
# 3  김승현     음악학과  tmdgus_skfk@naver.com      wnshite
# 4  김윤식   중국통상학과     manylong@naver.com  rladbstlr87

# %%
df2 = df[['이름', 'email']]

# %%
df2.to_csv('data/sample.csv')

# %%
excel2 = pd.read_excel('data/DAMF2.xlsx', sheet_name='info')
excel2.head()
# Out:
#     이름       전공                  email       github
# 0  오창희  소프트웨어공학     oche.edu@gmail.com      5chang2
# 1  권기남   항공전기전공     rlska213@naver.com       kka712
# 2  김광성     경제학과      kgs3770@gmail.com      kgs3770
# 3  김승현     음악학과  tmdgus_skfk@naver.com      wnshite
# 4  김윤식   중국통상학과     manylong@naver.com  rladbstlr87

# %%
csv = pd.read_csv('data/방위사업청_방산업체 지정현황_20071231.csv')

# %%
csv.head()
# Out:
#    순번    업체명  분야        지정일자   비고
# 0   1     강남  함정  1975-10-01  NaN
# 1   2   경주전장  항공  2004-03-01  NaN
# 2   3     광림  기동  1988-01-01  NaN
# 3   4   극동통신  유도  2002-12-01  NaN
# 4   5  금호타이어  항공  1975-10-01  NaN

# %%
csv2 = csv[['지정일자', '업체명', '분야']]

# %%
csv_df = pd.DataFrame(csv2)

# %%
csv_df
# Out:
#           지정일자     업체명  분야
# 0   1975-10-01      강남  함정
# 1   2004-03-01    경주전장  항공
# 2   1988-01-01      광림  기동
# 3   2002-12-01    극동통신  유도
# 4   1975-10-01   금호타이어  항공
# ..         ...     ...  ..
# 83  1984-05-01    LS전선  기동
# 84  1982-04-01   S&T대우  화력
# 85  1973-04-01  S&T중공업  화력
# 86  1977-07-01   STX엔진  기동
# 87  2007-09-01   STX조선  함정
#
# [88 rows x 3 columns]

# %%
csv_df['지정일자'] = pd.to_datetime(csv_df['지정일자'])
df_sorted = csv_df.sort_values(by='지정일자')
df_sorted.to_csv('sample2.csv')
new = pd.DataFrame(df_sorted)

# %%
# Out:
#          지정일자        업체명    분야
# 14 1972-05-01       대원강업    기타
# 77 1973-04-01  현대두산인프라코어    기동
# 38 1973-04-01    서울엔지니어링    기타
# 75 1973-04-01         한화    탄약
# 45 1973-04-01     알코아코리아    탄약
# ..        ...        ...   ...
# 8  2007-02-01     단암시스템즈  항공유도
# 30 2007-03-01      비젼이노텍    항공
# 39 2007-03-01      성진테크윈  항공유도
# 41 2007-03-01     수원지관산업    탄약
# 87 2007-09-01      STX조선    함정
#
# [88 rows x 3 columns]

# %%
new
# Out:
#          지정일자        업체명    분야
# 14 1972-05-01       대원강업    기타
# 77 1973-04-01  현대두산인프라코어    기동
# 38 1973-04-01    서울엔지니어링    기타
# 75 1973-04-01         한화    탄약
# 45 1973-04-01     알코아코리아    탄약
# ..        ...        ...   ...
# 8  2007-02-01     단암시스템즈  항공유도
# 30 2007-03-01      비젼이노텍    항공
# 39 2007-03-01      성진테크윈  항공유도
# 41 2007-03-01     수원지관산업    탄약
# 87 2007-09-01      STX조선    함정
#
# [86 rows x 3 columns]

# %%
cond = new['분야'] == '탄약'
new2 = new[cond]

# %%
new2
# Out:
#          지정일자     업체명  분야
# 75 1973-04-01      한화  탄약
# 45 1973-04-01  알코아코리아  탄약
# 73 1973-04-01  한일단조공업  탄약
# 64 1973-04-01      풍산  탄약
# 36 1979-02-01  삼양화학공업  탄약
# 65 1979-07-01   풍산FNS  탄약
# 18 2001-06-01    동양정공  탄약
# 41 2007-03-01  수원지관산업  탄약

# %%
new2.columns
# Out:
# Index(['지정일자', '업체명', '분야'], dtype='object')

# %%
new2.dtypes
# Out:
# 지정일자    datetime64[ns]
# 업체명             object
# 분야              object
# dtype: object

# %%
new2.rename(columns={'지정일자': 'date', '업체명': 'name', '분야': 'field'}, inplace=True)
new2.to_csv('data/sample3.csv')
# Out:
# C:\Users\1-09\AppData\Local\Temp\ipykernel_13160\3972648033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new2.rename(columns={'지정일자': 'date', '업체명': 'name', '분야': 'field'}, inplace=True)

# %%
new2
# Out:
#          date    name field
# 75 1973-04-01      한화    탄약
# 45 1973-04-01  알코아코리아    탄약
# 73 1973-04-01  한일단조공업    탄약
# 64 1973-04-01      풍산    탄약
# 36 1979-02-01  삼양화학공업    탄약
# 65 1979-07-01   풍산FNS    탄약
# 18 2001-06-01    동양정공    탄약
# 41 2007-03-01  수원지관산업    탄약

# %%
import matplotlib.pyplot as plt

new2['date'].hist()
plt.title('Distribution of Companies by Date')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

new['지정일자'].hist()
plt.title('Distribution of Companies by Date')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.show()
